# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
from datetime import datetime
from itertools import product
import json
import multiprocessing

# this is just a file with a worker function for multiprocessing
# (otherwise multiprocessing doesn't work in Jupyter on Windows)
#import worker

# %%
# brand names have been coppied from auto.ru manually and stored in brands.xlsx
df_brands = pd.read_excel('brands.xlsx')
df_brands
# Out:
#          Brands  Count
# 0            AC      2
# 1           AMC      2
# 2         Acura     46
# 3    Alfa Romeo     27
# 4        Alpina      2
# ..          ...    ...
# 120        ЛуАЗ     11
# 121     Москвич    101
# 122         СМЗ      1
# 123       ТагАЗ     34
# 124         УАЗ    450
#
# [125 rows x 2 columns]

# %%
# let's remove rare (<400) and Russian/Soviet brands
df_brands = df_brands[(df_brands['Count'] > 400) & ~(df_brands['Brands'].isin(['LADA (ВАЗ)', 'ГАЗ', 'УАЗ']))]

# %%
df_brands
# Out:
#             Brands  Count
# 8             Audi   2750
# 9              BMW   5283
# 19       Chevrolet   1352
# 21         Citroen    692
# 39            Ford   2017
# 51           Honda    574
# 53         Hyundai   3470
# 54        Infiniti    599
# 59            Jeep    401
# 60             Kia   3850
# 64      Land Rover   1192
# 65           Lexus    699
# 70            MINI    494
# 73           Mazda   1333
# 75   Mercedes-Benz   8770
# 78      Mitsubishi   2449
# 80          Nissan   3855
# 82            Opel   1411
# 85         Peugeot    754
# 88         Porsche    596
# 92         Renault   2790
# 99           Skoda   2378
# 102         Subaru    484
# 103         Suzuki    830
# 105         Toyota   2465
# 107     Volkswagen   4621
# 108          Volvo   1285

# %%
def crawl_auto(brands_lst, year_from=1980, year_to=2021, fr=1, to=10000000, radius=200):
    """
    This function crawls auto.ru. Idea for this function was 
    taken from https://github.com/DarkLabel1/YouTube/blob/master/Auto_ru.py
    
    After that it was slightly modified to fit the requirements of kaggle competition
    
    Arguments:
        brands - a list of brands to process
        year_from and year_to - range of car production years
        fr and to - used for testing (you can slice year_brand list to make the output longer or shorter
        if you need to test something)
        radius - radius from Moscow
    """
    # capitalize brand names
    brands = brands_lst.copy()
    brands = [b.upper() for b in brands]
    
    # all the years to consider
    year_range = list(np.arange(year_from, year_to))
    
    # pairs of year and brand to iterate over them
    year_brand = list(product(year_range, brands))
    
    # these 2 won't change
    URL = 'https://auto.ru/-/ajax/desktop/listing/' #URL for the post request

    # header for the post request
    HEADERS = {
        'Accept': '*/*',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3',
        'Connection': 'keep-alive',
        'Content-Length': '137',
        'content-type': 'application/json',
        'Cookie': 'autoru_gdpr=1; _csrf_token=1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24; autoru_sid=a%3Ag5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270%7C1580931467355.604800.8HnYnADZ6dSuzP1gctE0Fw.cd59AHgDSjoJxSYHCHfDUoj-f2orbR5pKj6U0ddu1G4; autoruuid=g5e3b198b299o5jhpv6nlk0ro4daqbpf.fa3630dbc880ea80147c661111fb3270; suid=48a075680eac323f3f9ad5304157467a.bc50c5bde34519f174ccdba0bd791787; from_lifetime=1580933172327; from=yandex; X-Vertis-DC=myt; crookie=bp+bI7U7P7sm6q0mpUwAgWZrbzx3jePMKp8OPHqMwu9FdPseXCTs3bUqyAjp1fRRTDJ9Z5RZEdQLKToDLIpc7dWxb90=; cmtchd=MTU4MDkzMTQ3MjU0NQ==; yandexuid=1758388111580931457; bltsr=1; navigation_promo_seen-recalls=true',
        'Host': 'auto.ru',
        'origin': 'https://auto.ru',
        'Referer': 'https://auto.ru/ryazan/cars/mercedes/all/',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
        'x-client-app-version': '202002.03.092255',
        'x-client-date': '1580933207763',
        'x-csrf-token': '1c0ed592ec162073ac34d79ce511f0e50d195f763abd8c24',
        'x-page-request-id': '60142cd4f0c0edf51f96fd0134c6f02a',
        'x-requested-with': 'fetch'
    }    
    
    result = []
    
    for yb in year_brand[fr:to]:  
        i = 1 # initializing i for pagination 
        l = 1 # initializing l that will be replaced by len(data) below
        while l > 0:
            # Post request parameters are changed within the loop
            PARAMS = {
                 'catalog_filter' : [{"mark": yb[1]}],
                 'section': "all",
                 'category': "cars",
                 'sort': "fresh_relevance_1-desc",
                 'page': i,
                 'geo_radius' : str(radius),
                 'year_from' : str(yb[0]),
                 'year_to' : str(yb[0]),
                 'geo_id' : [213]
                }

            i+=1
            
            response = requests.post(URL, json=PARAMS, headers=HEADERS) 
            try:
                data = response.json()['offers']
            except: 
                print(f'Failed for {yb[1]}, year {yb[0]} page {i} - let us go on!')
                
            l = len(data)
            if l > 0:
                print(f'{yb[1]}, year {yb[0]} : {l} entries')
                for o in data:
                    result.append(o)
    
    print('Crawling done!!!')
    return result;

# %%
def save_to_file(j):
    """
    Saves a json string to a file
    """
    jsonString = json.dumps(j, indent=4)
    with open("data.json", "w") as f:
        f.write(jsonString)

# %%
j = crawl_auto(brands_lst=list(df_brands['Brands']), year_from=1900, year_to=2022)

# I didn't have time to complete the parser in one go. That's why I decided to save the results to JSON and process
# this file later. The file for Moscow (+200 KM radius) and all the main brands starting from 1970 takes about 1.9 GB. Please
# take that into account if you decide to use the same approach.
save_to_file(j)
# Out:
# FORD, year 1923 : 1 entries
# FORD, year 1927 : 1 entries
# FORD, year 1928 : 1 entries
# FORD, year 1932 : 2 entries
# BMW, year 1937 : 2 entries
# AUDI, year 1938 : 1 entries
# OPEL, year 1938 : 1 entries
# FORD, year 1939 : 1 entries
# OPEL, year 1939 : 1 entries
# BMW, year 1947 : 1 entries
# BMW, year 1948 : 1 entries
# BMW, year 1949 : 2 entries
# FORD, year 1949 : 1 entries
# BMW, year 1950 : 2 entries
# FORD, year 1950 : 1 entries
# BMW, year 1951 : 1 entries
# CHEVROLET, year 1951 : 1 entries
# OPEL, year 1954 : 1 entries
# CHEVROLET, year 1955 : 1 entries
# PORSCHE, year 1956 : 1 entries
# FORD, year 1957 : 1 entries
# CHEVROLET, year 1959 : 1 entries
# PORSCHE, year 1959 : 1 entries
# SKODA, year 1960 : 1 entries
# CHEVROLET, year 1964 : 1 entries
# PORSCHE, year 1964 : 1 entries
# VOLKSWAGEN, year 1964 : 1 entries
# VOLKSWAGEN, year 1965 : 1 entries
# CITROEN, year 1967 : 1 entries
# BMW, year 1969 : 1 entries
# OPEL, year 1969 : 1 entries
# SUZUKI, year 1999 : 8 entries
# TOYOTA, year 1999 : 37 entries
# TOYOTA, year 1999 : 24 entries
# VOLKSWAGEN, year 1999 : 38 entries
# VOLKSWAGEN, year 1999 : 28 entries
# VOLVO, year 1999 : 6 entries
# AUDI, year 2000 : 37 entries
# AUDI, year 2000 : 1 entries
# BMW, year 2000 : 37 entries
# BMW, year 2000 : 7 entries
# CHEVROLET, year 2000 : 3 entries
# CITROEN, year 2000 : 2 entries
# FORD, year 2000 : 32 entries
# HONDA, year 2000 : 21 entries
# HYUNDAI, year 2000 : 11 entries
# INFINITI, year 2000 : 3 entries
# JEEP, year 2000 : 5 entries
# KIA, year 2000 : 14 entries
# LEXUS, year 2000 : 6 entries
# MAZDA, year 2000 : 24 entries
# MITSUBISHI, year 2000 : 38 entries
# MITSUBISHI, year 2000 : 28 entries
# NISSAN, year 2000 : 37 entries
# NISSAN, year 2000 : 16 entries
# OPEL, year 2000 : 37 entries
# OPEL, year 2000 : 1 entries
# PEUGEOT, year 2000 : 18 entries
# PORSCHE, year 2000 : 3 entries
# RENAULT, year 2000 : 9 entries
# SKODA, year 2000 : 12 entries
# SUBARU, year 2000 : 19 entries
# SUZUKI, year 2000 : 16 entries
# TOYOTA, year 2000 : 38 entries
# TOYOTA, year 2000 : 7 entries
# VOLKSWAGEN, year 2000 : 38 entries
# VOLKSWAGEN, year 2000 : 22 entries
# VOLVO, year 2000 : 6 entries
# AUDI, year 2001 : 34 entries
# BMW, year 2001 : 37 entries
# BMW, year 2001 : 33 entries
# CHEVROLET, year 2001 : 9 entries
# CITROEN, year 2001 : 5 entries
# FORD, year 2001 : 38 entries
# FORD, year 2001 : 5 entries
# HONDA, year 2001 : 30 entries
# HYUNDAI, year 2001 : 24 entries
# JEEP, year 2001 : 7 entries
# KIA, year 2001 : 11 entries
# LEXUS, year 2001 : 12 entries
# MAZDA, year 2001 : 24 entries
# MITSUBISHI, year 2001 : 38 entries
# MITSUBISHI, year 2001 : 24 entries
# NISSAN, year 2001 : 37 entries
# NISSAN, year 2001 : 18 entries
# OPEL, year 2001 : 25 entries
# PEUGEOT, year 2001 : 25 entries
# RENAULT, year 2001 : 22 entries
# SKODA, year 2001 : 19 entries
# SUBARU, year 2001 : 15 entries
# SUZUKI, year 2001 : 11 entries
# TOYOTA, year 2001 : 37 entries
# TOYOTA, year 2001 : 33 entries
# VOLKSWAGEN, year 2001 : 38 entries
# VOLKSWAGEN, year 2001 : 37 entries
# VOLKSWAGEN, year 2001 : 3 entries
# VOLVO, year 2001 : 20 entries
# AUDI, year 2002 : 37 entries
# AUDI, year 2002 : 20 entries
# BMW, year 2002 : 38 entries
# BMW, year 2002 : 30 entries
# CHEVROLET, year 2002 : 7 entries
# CITROEN, year 2002 : 10 entries
# FORD, year 2002 : 37 entries
# FORD, year 2002 : 9 entries
# HONDA, year 2002 : 30 entries
# HYUNDAI, year 2002 : 37 entries
# HYUNDAI, year 2002 : 16 entries
# INFINITI, year 2002 : 3 entries
# JEEP, year 2002 : 3 entries
# KIA, year 2002 : 31 entries
# LEXUS, year 2002 : 12 entries
# MINI, year 2002 : 4 entries
# MAZDA, year 2002 : 21 entries
# MITSUBISHI, year 2002 : 37 entries
# MITSUBISHI, year 2002 : 37 entries
# MITSUBISHI, year 2002 : 2 entries
# NISSAN, year 2002 : 38 entries
# NISSAN, year 2002 : 17 entries
# OPEL, year 2002 : 19 entries
# PEUGEOT, year 2002 : 26 entries
# PORSCHE, year 2002 : 2 entries
# RENAULT, year 2002 : 27 entries
# SKODA, year 2002 : 32 entries
# SUBARU, year 2002 : 15 entries
# SUZUKI, year 2002 : 18 entries
# TOYOTA, year 2002 : 37 entries
# TOYOTA, year 2002 : 27 entries
# VOLKSWAGEN, year 2002 : 37 entries
# VOLKSWAGEN, year 2002 : 37 entries
# VOLVO, year 2002 : 15 entries
# AUDI, year 2003 : 29 entries
# BMW, year 2003 : 37 entries
# BMW, year 2003 : 16 entries
# CHEVROLET, year 2003 : 22 entries
# CITROEN, year 2003 : 6 entries
# FORD, year 2003 : 38 entries
# FORD, year 2003 : 23 entries
# HONDA, year 2003 : 23 entries
# HYUNDAI, year 2003 : 38 entries
# HYUNDAI, year 2003 : 7 entries
# INFINITI, year 2003 : 16 entries
# JEEP, year 2003 : 6 entries
# KIA, year 2003 : 30 entries
# LEXUS, year 2003 : 16 entries
# MINI, year 2003 : 2 entries
# MAZDA, year 2003 : 18 entries
# MITSUBISHI, year 2003 : 37 entries
# MITSUBISHI, year 2003 : 37 entries
# MITSUBISHI, year 2003 : 20 entries
# NISSAN, year 2003 : 38 entries
# NISSAN, year 2003 : 36 entries
# OPEL, year 2003 : 31 entries
# PEUGEOT, year 2003 : 31 entries
# PORSCHE, year 2003 : 10 entries
# RENAULT, year 2003 : 22 entries
# SKODA, year 2003 : 17 entries
# SUBARU, year 2003 : 13 entries
# SUZUKI, year 2003 : 20 entries
# TOYOTA, year 2003 : 38 entries
# TOYOTA, year 2003 : 37 entries
# TOYOTA, year 2003 : 1 entries
# VOLKSWAGEN, year 2003 : 37 entries
# VOLKSWAGEN, year 2003 : 16 entries
# VOLVO, year 2003 : 28 entries
# AUDI, year 2004 : 37 entries
# AUDI, year 2004 : 7 entries
# BMW, year 2004 : 38 entries
# BMW, year 2004 : 37 entries
# BMW, year 2004 : 16 entries
# CHEVROLET, year 2004 : 38 entries
# CHEVROLET, year 2004 : 30 entries
# CITROEN, year 2004 : 18 entries
# FORD, year 2004 : 38 entries
# FORD, year 2004 : 37 entries
# FORD, year 2004 : 17 entries
# HONDA, year 2004 : 12 entries
# HYUNDAI, year 2004 : 38 entries
# HYUNDAI, year 2004 : 37 entries
# HYUNDAI, year 2004 : 34 entries
# INFINITI, year 2004 : 10 entries
# JEEP, year 2004 : 16 entries
# KIA, year 2004 : 37 entries
# KIA, year 2004 : 3 entries
# LEXUS, year 2004 : 10 entries
# MINI, year 2004 : 1 entries
# MAZDA, year 2004 : 37 entries
# MAZDA, year 2004 : 14 entries
# MITSUBISHI, year 2004 : 38 entries
# MITSUBISHI, year 2004 : 37 entries
# MITSUBISHI, year 2004 : 34 entries
# NISSAN, year 2004 : 38 entries
# NISSAN, year 2004 : 37 entries
# NISSAN, year 2004 : 17 entries
# OPEL, year 2004 : 30 entries
# PEUGEOT, year 2004 : 27 entries
# PORSCHE, year 2004 : 24 entries
# RENAULT, year 2004 : 36 entries
# SKODA, year 2004 : 11 entries
# SUBARU, year 2004 : 19 entries
# SUZUKI, year 2004 : 11 entries
# TOYOTA, year 2004 : 38 entries
# TOYOTA, year 2004 : 19 entries
# VOLKSWAGEN, year 2004 : 37 entries
# VOLKSWAGEN, year 2004 : 32 entries
# VOLVO, year 2004 : 32 entries
# AUDI, year 2005 : 37 entries
# AUDI, year 2005 : 9 entries
# BMW, year 2005 : 38 entries
# BMW, year 2005 : 37 entries
# BMW, year 2005 : 14 entries
# CHEVROLET, year 2005 : 38 entries
# CHEVROLET, year 2005 : 37 entries
# CHEVROLET, year 2005 : 24 entries
# CITROEN, year 2005 : 21 entries
# FORD, year 2005 : 38 entries
# FORD, year 2005 : 37 entries
# FORD, year 2005 : 29 entries
# HONDA, year 2005 : 16 entries
# HYUNDAI, year 2005 : 38 entries
# HYUNDAI, year 2005 : 37 entries
# HYUNDAI, year 2005 : 37 entries
# HYUNDAI, year 2005 : 13 entries
# INFINITI, year 2005 : 14 entries
# JEEP, year 2005 : 7 entries
# KIA, year 2005 : 37 entries
# KIA, year 2005 : 14 entries
# LEXUS, year 2005 : 19 entries
# MINI, year 2005 : 3 entries
# MAZDA, year 2005 : 38 entries
# MAZDA, year 2005 : 33 entries
# MITSUBISHI, year 2005 : 38 entries
# MITSUBISHI, year 2005 : 37 entries
# MITSUBISHI, year 2005 : 37 entries
# MITSUBISHI, year 2005 : 15 entries
# NISSAN, year 2005 : 38 entries
# NISSAN, year 2005 : 37 entries
# NISSAN, year 2005 : 19 entries
# OPEL, year 2005 : 14 entries
# PEUGEOT, year 2005 : 20 entries
# PORSCHE, year 2005 : 16 entries
# RENAULT, year 2005 : 38 entries
# SKODA, year 2005 : 14 entries
# SUBARU, year 2005 : 23 entries
# SUZUKI, year 2005 : 23 entries
# TOYOTA, year 2005 : 37 entries
# TOYOTA, year 2005 : 14 entries
# VOLKSWAGEN, year 2005 : 37 entries
# VOLKSWAGEN, year 2005 : 37 entries
# VOLKSWAGEN, year 2005 : 7 entries
# VOLVO, year 2005 : 23 entries
# AUDI, year 2006 : 37 entries
# AUDI, year 2006 : 37 entries
# AUDI, year 2006 : 3 entries
# BMW, year 2006 : 38 entries
# BMW, year 2006 : 22 entries
# CHEVROLET, year 2006 : 38 entries
# CHEVROLET, year 2006 : 37 entries
# CHEVROLET, year 2006 : 37 entries
# CHEVROLET, year 2006 : 37 entries
# CHEVROLET, year 2006 : 35 entries
# CITROEN, year 2006 : 37 entries
# CITROEN, year 2006 : 4 entries
# FORD, year 2006 : 38 entries
# FORD, year 2006 : 37 entries
# FORD, year 2006 : 37 entries
# FORD, year 2006 : 37 entries
# FORD, year 2006 : 37 entries
# FORD, year 2006 : 37 entries
# SKODA, year 2012 : 38 entries
# SKODA, year 2012 : 37 entries
# SKODA, year 2012 : 37 entries
# SKODA, year 2012 : 37 entries
# SKODA, year 2012 : 37 entries
# SKODA, year 2012 : 36 entries
# SUBARU, year 2012 : 32 entries
# SUZUKI, year 2012 : 31 entries
# TOYOTA, year 2012 : 38 entries
# TOYOTA, year 2012 : 37 entries
# TOYOTA, year 2012 : 37 entries
# TOYOTA, year 2012 : 37 entries
# TOYOTA, year 2012 : 11 entries
# VOLKSWAGEN, year 2012 : 38 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 37 entries
# VOLKSWAGEN, year 2012 : 30 entries
# VOLVO, year 2012 : 38 entries
# VOLVO, year 2012 : 37 entries
# VOLVO, year 2012 : 9 entries
# AUDI, year 2013 : 38 entries
# AUDI, year 2013 : 37 entries
# AUDI, year 2013 : 37 entries
# AUDI, year 2013 : 37 entries
# AUDI, year 2013 : 37 entries
# AUDI, year 2013 : 10 entries
# BMW, year 2013 : 38 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 37 entries
# BMW, year 2013 : 15 entries
# CHEVROLET, year 2013 : 38 entries
# CHEVROLET, year 2013 : 37 entries
# CHEVROLET, year 2013 : 37 entries
# CHEVROLET, year 2013 : 37 entries
# CHEVROLET, year 2013 : 37 entries
# CHEVROLET, year 2013 : 37 entries
# CHEVROLET, year 2013 : 8 entries
# CITROEN, year 2013 : 37 entries
# CITROEN, year 2013 : 37 entries
# CITROEN, year 2013 : 3 entries
# FORD, year 2013 : 38 entries
# FORD, year 2013 : 37 entries
# FORD, year 2013 : 37 entries
# FORD, year 2013 : 37 entries
# FORD, year 2013 : 37 entries
# FORD, year 2013 : 37 entries
# FORD, year 2013 : 13 entries
# HONDA, year 2013 : 38 entries
# HONDA, year 2013 : 25 entries
# HYUNDAI, year 2013 : 38 entries
# HYUNDAI, year 2013 : 37 entries
# HYUNDAI, year 2013 : 37 entries
# HYUNDAI, year 2013 : 37 entries
# HYUNDAI, year 2013 : 37 entries
# HYUNDAI, year 2013 : 37 entries
# HYUNDAI, year 2013 : 20 entries
# INFINITI, year 2013 : 37 entries
# INFINITI, year 2013 : 18 entries
# JEEP, year 2013 : 31 entries
# KIA, year 2013 : 38 entries
# KIA, year 2013 : 37 entries
# KIA, year 2013 : 37 entries
# KIA, year 2013 : 37 entries
# KIA, year 2013 : 37 entries
# KIA, year 2013 : 37 entries
# KIA, year 2013 : 37 entries
# KIA, year 2013 : 25 entries
# LEXUS, year 2013 : 37 entries
# LEXUS, year 2013 : 8 entries
# MINI, year 2013 : 22 entries
# MAZDA, year 2013 : 37 entries
# MAZDA, year 2013 : 37 entries
# MAZDA, year 2013 : 19 entries
# MITSUBISHI, year 2013 : 38 entries
# MITSUBISHI, year 2013 : 37 entries
# MITSUBISHI, year 2013 : 37 entries
# NISSAN, year 2013 : 37 entries
# NISSAN, year 2013 : 37 entries
# NISSAN, year 2013 : 37 entries
# NISSAN, year 2013 : 37 entries
# NISSAN, year 2013 : 37 entries
# NISSAN, year 2013 : 37 entries
# NISSAN, year 2013 : 30 entries
# OPEL, year 2013 : 38 entries
# OPEL, year 2013 : 37 entries
# OPEL, year 2013 : 37 entries
# OPEL, year 2013 : 37 entries
# OPEL, year 2013 : 37 entries
# OPEL, year 2013 : 36 entries
# PEUGEOT, year 2013 : 37 entries
# PEUGEOT, year 2013 : 33 entries
# PORSCHE, year 2013 : 37 entries
# PORSCHE, year 2013 : 11 entries
# RENAULT, year 2013 : 38 entries
# RENAULT, year 2013 : 37 entries
# RENAULT, year 2013 : 37 entries
# RENAULT, year 2013 : 37 entries
# RENAULT, year 2013 : 37 entries
# RENAULT, year 2013 : 16 entries
# SKODA, year 2013 : 38 entries
# SKODA, year 2013 : 37 entries
# SKODA, year 2013 : 37 entries
# SKODA, year 2013 : 37 entries
# SKODA, year 2013 : 21 entries
# SUBARU, year 2013 : 25 entries
# SUZUKI, year 2013 : 29 entries
# TOYOTA, year 2013 : 38 entries
# TOYOTA, year 2013 : 37 entries
# TOYOTA, year 2013 : 37 entries
# TOYOTA, year 2013 : 37 entries
# TOYOTA, year 2013 : 37 entries
# TOYOTA, year 2013 : 18 entries
# VOLKSWAGEN, year 2013 : 38 entries
# VOLKSWAGEN, year 2013 : 37 entries
# VOLKSWAGEN, year 2013 : 37 entries
# VOLKSWAGEN, year 2013 : 37 entries
# VOLKSWAGEN, year 2013 : 37 entries
# VOLKSWAGEN, year 2013 : 37 entries
# VOLKSWAGEN, year 2013 : 37 entries
# VOLKSWAGEN, year 2013 : 37 entries
# VOLKSWAGEN, year 2013 : 12 entries
# VOLVO, year 2013 : 37 entries
# VOLVO, year 2013 : 28 entries
# AUDI, year 2014 : 38 entries
# AUDI, year 2014 : 37 entries
# AUDI, year 2014 : 37 entries
# AUDI, year 2014 : 37 entries
# AUDI, year 2014 : 11 entries
# BMW, year 2014 : 38 entries
# BMW, year 2014 : 37 entries
# BMW, year 2014 : 37 entries
# BMW, year 2014 : 37 entries
# BMW, year 2014 : 37 entries
# BMW, year 2014 : 37 entries
# BMW, year 2014 : 37 entries
# BMW, year 2014 : 11 entries
# CHEVROLET, year 2014 : 38 entries
# CHEVROLET, year 2014 : 37 entries
# CHEVROLET, year 2014 : 37 entries
# CHEVROLET, year 2014 : 37 entries
# CHEVROLET, year 2014 : 35 entries
# CITROEN, year 2014 : 38 entries
# CITROEN, year 2014 : 23 entries
# FORD, year 2014 : 37 entries
# FORD, year 2014 : 37 entries
# FORD, year 2014 : 37 entries
# FORD, year 2014 : 32 entries
# HONDA, year 2014 : 29 entries
# HYUNDAI, year 2014 : 38 entries
# HYUNDAI, year 2014 : 37 entries
# HYUNDAI, year 2014 : 37 entries
# HYUNDAI, year 2014 : 37 entries
# HYUNDAI, year 2014 : 37 entries
# HYUNDAI, year 2014 : 37 entries
# HYUNDAI, year 2014 : 25 entries
# INFINITI, year 2014 : 37 entries
# INFINITI, year 2014 : 25 entries
# JEEP, year 2014 : 34 entries
# KIA, year 2014 : 38 entries
# KIA, year 2014 : 37 entries
# KIA, year 2014 : 37 entries
# KIA, year 2014 : 37 entries
# KIA, year 2014 : 37 entries
# KIA, year 2014 : 37 entries
entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 37 entries
# BMW, year 2021 : 33 entries
# CITROEN, year 2021 : 19 entries
# FORD, year 2021 : 1 entries
# HYUNDAI, year 2021 : 37 entries
# HYUNDAI, year 2021 : 37 entries
# HYUNDAI, year 2021 : 37 entries
# HYUNDAI, year 2021 : 22 entries
# KIA, year 2021 : 34 entries
# LEXUS, year 2021 : 4 entries
# MINI, year 2021 : 37 entries
# MINI, year 2021 : 31 entries
# MAZDA, year 2021 : 23 entries
# MITSUBISHI, year 2021 : 13 entries
# NISSAN, year 2021 : 37 entries
# NISSAN, year 2021 : 37 entries
# NISSAN, year 2021 : 37 entries
# NISSAN, year 2021 : 37 entries
# NISSAN, year 2021 : 37 entries
# NISSAN, year 2021 : 37 entries
# NISSAN, year 2021 : 30 entries
# OPEL, year 2021 : 32 entries
# PEUGEOT, year 2021 : 14 entries
# PORSCHE, year 2021 : 3 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 37 entries
# RENAULT, year 2021 : 5 entries
# SKODA, year 2021 : 37 entries
# SKODA, year 2021 : 17 entries
# SUZUKI, year 2021 : 37 entries
# SUZUKI, year 2021 : 37 entries
# SUZUKI, year 2021 : 37 entries
# SUZUKI, year 2021 : 37 entries
# SUZUKI, year 2021 : 37 entries
# SUZUKI, year 2021 : 37 entries
# SUZUKI, year 2021 : 15 entries
# TOYOTA, year 2021 : 37 entries
# TOYOTA, year 2021 : 15 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 37 entries
# VOLKSWAGEN, year 2021 : 30 entries
# VOLVO, year 2021 : 37 entries
# VOLVO, year 2021 : 37 entries
# VOLVO, year 2021 : 37 entries
# VOLVO, year 2021 : 37 entries
# VOLVO, year 2021 : 37 entries
# VOLVO, year 2021 : 37 entries
# VOLVO, year 2021 : 29 entries
# Crawling done!!!

# %%
len(j)
# Out:
# 60488

# %%
import json

def process_json_array(f):
    """
    This function processes the contents of a json file (please see save_to_json for details) to extract only the required
    attributes
    """
    with open(f, "r") as f:
        data = json.load(f)
    
    return data

# %%
from_json = process_json_array('data 3.json')

# %%
from_json[0]
# Out:
# {'availability': 'IN_STOCK',
#  'category': 'cars',
#  'color_hex': '007F00',
#  'delivery_info': {},
#  'description': '1 октября 1908 Форд воплотил в жизнь свою мечту создать "автомобиль для народа" выпустив модель Т - надежный и недорогой автомобиль , способный пройти там, где другие машины застревали в дорожной грязи.\nв первый год производства было продано 10 660 машин.\nАвтомобиль в идеальном состоянии.\nОтносится к категории культурных ценностей.\nДанный автомобиль Вы можете обменять на свой.\n\nВозможен торг.',
#  'discount_options': {},
#  'documents': {'owners_number': 1,
#   'pts_original': True,
#   'custom_cleared': True,
#   'year': 1923,
#   'pts': 'ORIGINAL'},
#  'is_favorite': False,
#  'old_category_id': 15,
#  'owner_expenses': {'transport_tax': {'tax_by_year': 240,
#    'year': 2020,
#    'rid': 213,
#    'rate': 12,
#    'horse_power': 20,
#    'holding_period_month': 12,
#    'boost': 1},
#   'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 2366}]},
#  'section': 'used',
#  'seller_type': 'COMMERCIAL',
#  'status': 'ACTIVE',
#  'tags': ['compact',
#   'style',
#   'low_mileage',
#   'dealer_quarantine_calls',
#   'pts_original'],
#  'additional_info': {'hidden': False,
#   'is_on_moderation': False,
#   'exchange': True,
#   'update_date': '1610726578000',
#   'creation_date': '1545845221000',
#   'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/FORD/?geo_id=213',
#   'hot_info': {'is_hot': False,
#    'start_time': '2018-12-26T17:36:01Z',
#    'end_time': '2018-12-26T17:36:01Z'},
#   'fresh_date': '1545845221000',
#   'counters_start_date': '1545845221000',
#   'chat_only': False,
#   'dealer_card_promo': 'DONT_SHOW',
#   'review_summary': {},
#   'price_stats': {},
#   'booking': {},
#   'days_in_stock': 751,
#   'days_on_sale': 751},
#  'counters': {},
#  'grouping_info': None,
#  'hash': '76fa14fb',
#  'id': '1082754038',
#  'price_info': {'price': 3800000,
#   'currency': 'RUR',
#   'EUR': 42575,
#   'RUR': 3800000,
#   'USD': 51669,
#   'with_nds': False},
#  'price_history': [{'EUR': 42575,
#    'RUR': 3800000,
#    'USD': 51669,
#    'create_timestamp': 1545845761000}],
#  'recall_info': {},
#  'saleId': '1082754038-76fa14fb',
#  'salon': {'actual_stock': True,
#   'client_id': '16636',
#   'code': 'royalmotors_moskva',
#   'dealer_id': '20866551',
#   'offer_counters': {'cars_all': 62, 'moto_all': 6},
#   'name': 'RoyalMotors',
#   'phones': [{'phone': '+7 968 010-64-44'}],
#   'place': {'address': 'Кутузовский проспект, 2/1 здание конгресс парка минус 3 этаж',
#    'coord': {'latitude': 55.75168, 'longitude': 37.566386},
#    'geobase_id': '213',
#    'region_info': {'id': '213',
#     'name': 'Москва',
#     'genitive': 'Москвы',
#     'dative': 'Москве',
#     'accusative': 'Москву',
#     'prepositional': 'Москве',
#     'preposition': 'в',
#     'latitude': 55.753215,
#     'longitude': 37.622504,
#     'parent_ids': ['213', '1', '3', '225', '10001', '10000']},
#    'metro': [{'rid': '20449',
#      'name': 'Киевская',
#      'distance': 776.8141951715876,
#      'location': {'latitude': 55.744596, 'longitude': 37.567545},
#      'lines': [{'name': 'Арбатско-Покровская линия', 'color': '#0042a5'},
#       {'name': 'Кольцевая линия', 'color': '#794835'},
#       {'name': 'Филёвская линия', 'color': '#099dd4'}]},
#     {'rid': '20511',
#      'name': 'Краснопресненская',
#      'distance': 1165.6047017733522,
#      'location': {'latitude': 55.760211, 'longitude': 37.577211},
#      'lines': [{'name': 'Кольцевая линия', 'color': '#794835'}]}]},
#   'registration_date': '2015-03-13T14:02:58Z',
#   'salon_id': '10950',
#   'is_official': False},
#  'seller': {'location': {'address': 'Кутузовский проспект, 2/1 здание конгресс парка минус 3 этаж',
#    'coord': {'latitude': 55.751678, 'longitude': 37.566387},
#    'geobase_id': '213',
#    'region_info': {'id': '213',
#     'name': 'Москва',
#     'genitive': 'Москвы',
#     'dative': 'Москве',
#     'accusative': 'Москву',
#     'prepositional': 'Москве',
#     'preposition': 'в',
#     'latitude': 55.753215,
#     'longitude': 37.622504,
#     'parent_ids': ['213', '1', '3', '225', '10001', '10000']},
#    'metro': [{'rid': '20449',
#      'name': 'Киевская',
#      'distance': 776.8141951715876,
#      'location': {'latitude': 55.744596, 'longitude': 37.567545},
#      'lines': [{'name': 'Арбатско-Покровская линия', 'color': '#0042a5'},
1200x900n'},
#     'preview': 'data:image/jpeg;base64,...'}],
#   'images_count': 11},
#  'sub_category': 'cars',
#  'vehicle_info': {'configuration': {'id': '20650970',
#    'body_type': 'CABRIO',
#    'doors_count': 2,
#    'human_name': 'Кабриолет',
#    'body_type_group': 'CABRIO',
#    'main_photo': {'sizes': {'orig': '//avatars.mds.yandex.net/get-verba/787013/2a00000160928d0739c0956382fdbfae2e75/orig',
#      'wizardv3mr': '//avatars.mds.yandex.net/get-verba/787013/2a00000160928d0739c0956382fdbfae2e75/wizardv3mr',
#      'cattouch': '//avatars.mds.yandex.net/get-verba/787013/2a00000160928d0739c0956382fdbfae2e75/cattouch'}},
#    'tags': ['compact', 'style']},
#   'complectation': {'id': '0'},
#   'mark_info': {'code': 'FORD',
#    'name': 'Ford',
#    'ru_name': 'Форд',
#    'logo': {'name': 'mark-logo',
#     'sizes': {'logo': '//avatars.mds.yandex.net/get-verba/1540742/2a0000016d691c30185172465dd1125ee1a5/logo',
#      'big-logo': '//avatars.mds.yandex.net/get-verba/1540742/2a0000016d691c30185172465dd1125ee1a5/dealer_logo'}}},
#   'model_info': {'code': 'MODEL_T',
#    'name': 'Model T',
#    'ru_name': 'Модель Т',
#    'morphology': {},
#    'nameplate': {'code': '', 'name': '', 'semantic_url': ''}},
#   'steering_wheel': 'LEFT',
#   'super_gen': {'id': '20650941',
#    'year_from': 1908,
#    'year_to': 1927,
#    'price_segment': 'MEDIUM'},
#   'tech_param': {'id': '20650995',
#    'displacement': 2896,
#    'engine_type': 'GASOLINE',
#    'gear_type': 'REAR_DRIVE',
#    'transmission': 'MECHANICAL',
#    'power': 20,
#    'power_kvt': 15,
#    'human_name': '2.9 MT (20 л.с.)'},
#   'vendor': 'AMERICAN',
#   'equipment': {}},
#  'lk_summary': '2.9\xa0MT (20\xa0л.с.), кабриолет, задний, бензин',
#  'multiposting': {}}

# %%
from_json[60000]
# Out:
# {'availability': 'ON_ORDER',
#  'category': 'cars',
#  'color_hex': 'FAFBFB',
#  'delivery_info': {},
#  'description': 'Пакет "Зимние технологии"\nМногофункциональное рулевое колесо с кожаной отделкой и подогревом\nПодогрев передних сидений\nПодогрев боковых задних сидений\nИндикатор низкого уровня жидкости омывателя\nПодогрев форсунок омывателя\nЭлектроскладываемые наружные зеркала заднего вида с электрорегулировками и подогревом\nТеплоизолирующее лобовое стекло с электроподогревом\n\nВнешнее оборудование\n----------------------------\nЗадние стекла с тонировкой (65% светопоглощение)\nСветодиодные фары ближнего и дальнего света рефлекторного типа с отдельными дневными ходовыми огнями\nСветодиодные задние фонари\nРейлинги на крыше серебристого цвета\nХромированная окантовка боковых окон\nЛегкосплавные колесные диски "Montana" 7J x 17", шины 215/65 R17\n\nИнтерьер\n----------------------------\nТканевая отделка "Shooting Star"\nКарманы в спинках передних сидений\nДекоративные вставки Status\nСалонное зеркало заднего вида с автозатемнением\nПоясничный подпор для передних сидений\nПолностью складываемая спинка переднего пассажирского кресла\nЯщики для хранения под передними креслами\nФонарик в багажном отделении\nРозетка 230В в багажном отделении\nПодсветка в пространстве для ног\nОтсек для очков\n\nБезопасность\n----------------------------\nСистема контроля дистанции Front Assist с функцией экстренного торможения City Emergency Braking\nСистема распознавания усталости водителя\nСистема ЭРА ГЛОНАСС\nПередние подушки безопасности с функцией отключения пассажирской подушки\nБоковые шторки безопасности спереди и сзади и передние боковые подушки\nЭлектронная система стабилизации (ESP), антиблокировочная система (ABS) с функцией антипробуксовочной системы (ASR), электронная блокировка дифференциала (EDL) и стабилизация прицепа\n\nФункциональное оборудование\n----------------------------\nМногофункциональный цветной дисплей на приборной панели Premium\nТрёхзонная система климат-контроля Air Care Climatronic с фильтром пыльцы и сенсорным управлением спереди\nБеспроводной интерфейс для мобильного телефона Bluetooth\n8 динамиков\nЭлектромеханический стояночный тормоз с системой AutoHold\nДатчик дождя\nАвтоматическое управление ближним светом фар, функция `Coming Home`/`Leaving home´\nАвтокорректор фар\nДва порта USB Type-C в центральной консоли, один USB-порт Type-C для задних пассажиров (только зарядка)\nАссистент движения на спуске (для полного привода 4Motion)\nВыбор режимов движения\nКруиз-контроль с ограничителем скорости\nЭлектромеханический усилитель рулевого управления, с переменной эффективностью в зависимости от скорости\nАудиосистема "Discover Media" с цветным дисплеем 8" и навигацией\nИнтерфейс App-Connect (Apple Carplay, Android Auto, Mirrorlink)\nКамера заднего вида с омывателем\nСистема помощи при парковке спереди и сзади, Brake Assist\nСистема контроля давления в шинах\n\n* Стоимость данного автомобиля указана без учета предустановленного дополнительного оборудования.',
#  'discount_price': {'price': 2099900, 'status': 'ACTIVE'},
#  'discount_options': {'tradein': 40000, 'max_discount': 40000},
#  'documents': {'pts_original': True,
#   'custom_cleared': True,
#   'year': 2021,
#   'warranty': True,
#   'warranty_expire': {'year': 2024, 'month': 1, 'day': 1},
#   'pts': 'ORIGINAL'},
#  'is_favorite': False,
#  'old_category_id': 15,
#  'owner_expenses': {'transport_tax': {'tax_by_year': 5250,
#    'year': 2020,
#    'rid': 213,
#    'rate': 35,
#    'horse_power': 150,
#    'holding_period_month': 12,
#    'boost': 1},
#   'osago_insurance': [{'insurance_company': 'TINKOFF', 'price': 5521}]},
#  'section': 'new',
#  'seller_type': 'COMMERCIAL',
#  'status': 'ACTIVE',
#  'tags': ['new4new',
#   'discount',
#   'discount_options',
#   'comfort',
#   'dealer_discount',
#   'dealer_quarantine_calls',
#   'redemption'],
#  'additional_info': {'hidden': False,
#   'is_on_moderation': False,
#   'exchange': True,
#   'update_date': '1610720189000',
#   'creation_date': '1610451098000',
#   'mobile_autoservices_url': 'https://m.auto.ru/autoservice/all_works/VOLKSWAGEN/?geo_id=213',
#   'hot_info': {'is_hot': False,
#    'start_time': '2021-01-12T12:09:38Z',
#    'end_time': '2021-01-12T12:09:38Z'},
#   'redemption_available': True,
#   'fresh_date': '1610451098000',
#   'counters_start_date': '1610451098000',
#   'chat_only': False,
#   'dealer_card_promo': 'DONT_SHOW',
#   'review_summary': {},
#   'price_stats': {'last_year_price_percentage_diff': -9},
#   'booking': {},
#   'match_application_form': {'contexts': ['listing',
#     'group_card',
#     'gallery',
#     'footer',
#     'mixed-listing']},
#   'days_in_stock': 4,
#   'days_on_sale': 4},
#  'counters': {},
#  'grouping_info': None,
#  'hash': '2e96424f',
#  'id': '1102149070',
#  'price_info': {'price': 2139900,
#   'currency': 'RUR',
#   'EUR': 23975,
#   'RUR': 2139900,
#   'USD': 29096,
#   'with_nds': False},
#  'price_history': [{'EUR': 23975,
#    'RUR': 2139900,
#    'USD': 29096,
#    'create_timestamp': 1610453377000}],
#  'recall_info': {},
#  'saleId': '1102149070-2e96424f',
#  'salon': {'actual_stock': True,
#   'client_id': '8538',
#   'code': 'volkswagen_centr_losiny_ostrov_moskva',
#   'dealer_id': '20136850',
#   'logo_url': '//avatars.mds.yandex.net/get-verba/937147/2a00000169d836a9c098e13c996113d09deb/dealer_logo',
#   'offer_counters': {'cars_all': 264, 'trucks_all': 1},
#   'name': 'Volkswagen Центр Лосиный Остров',
#   'phones': [{'phone': '+7 495 598-58-58'}],
#   'place': {'address': 'Московская обл., Ярославское шоссе, владение 2В, строение 1 (95 км МКАД)',
#    'coord': {'latitude': 55.881573, 'longitude': 37.732727},
#    'geobase_id': '10740',
#    'region_info': {'id': '10740',
#     'name': 'Мытищи',
#     'genitive': 'Мытищ',
#     'dative': 'Мытищам',
#     'accusative': 'Мытищи',
#     'prepositional': 'Мытищах',
#     'preposition': 'в',
#     'latitude': 55.910503,
#     'longitude': 37.73633,
#     'parent_ids': ['10740', '98596', '1', '3', '225', '10001', '10000']}},
#   'registration_date': '2013-08-26T20:00:00Z',
#   'salon_id': '8495',
#   'is_official': True},
#  'seller': {'location': {'address': 'МО, г.Мытищи, Ярославское шоссе, владение 2В, строение 1',
#    'coord': {'latitude': 55.881485, 'longitude': 37.732735},
#    'geobase_id': '213',
#    'region_info': {'id': '213',
#     'name': 'Москва',
#     'genitive': 'Москвы',
#     'dative': 'Москве',
#     'accusative': 'Москву',
#     'prepositional': 'Москве',
#     'preposition': 'в',
#     'latitude': 55.753215,
#     'longitude': 37.622504,
#     'parent_ids': ['213', '1', '3', '225', '10001', '10000']},
#    'timezone_info': {'abbr': 'MSK',
#     'dst': False,
#     'name': 'Europe/Moscow',
#     'offset': 10800}},
#   'name': 'Volkswagen Центр Лосиный Остров',
#   'phones': [],
#   'redirect_phones': False,
#   'chats_enabled': False,
#   'call_hours': {'call_hour_start': 9,
#    'call_hour_end': 21,
#    'call_minute_end': 0,
#    'call_minute_start': 0}},
#  'service_prices': [],
#  'services': [],
#  'state': {'state_not_beaten': True,
#   'image_urls': [{'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1993805/3657fbaa2e722a91b492c6063733dfc5/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1993805/3657fbaa2e722a91b492c6063733dfc5/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1993805/3657fbaa2e722a91b492c6063733dfc5/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1993805/3657fbaa2e722a91b492c6063733dfc5/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1993805/3657fbaa2e722a91b492c6063733dfc5/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1993805/3657fbaa2e722a91b492c6063733dfc5/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1993805/3657fbaa2e722a91b492c6063733dfc5/1200x900n'},
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2080053/9c14be6c0f6ad12e1370182819a6fd1e/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2080053/9c14be6c0f6ad12e1370182819a6fd1e/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2080053/9c14be6c0f6ad12e1370182819a6fd1e/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2080053/9c14be6c0f6ad12e1370182819a6fd1e/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2080053/9c14be6c0f6ad12e1370182819a6fd1e/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2080053/9c14be6c0f6ad12e1370182819a6fd1e/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2080053/9c14be6c0f6ad12e1370182819a6fd1e/1200x900n'},
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2001319/fbb9ecacfb0bba34946e5ef10c1fdd6c/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2001319/fbb9ecacfb0bba34946e5ef10c1fdd6c/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2001319/fbb9ecacfb0bba34946e5ef10c1fdd6c/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2001319/fbb9ecacfb0bba34946e5ef10c1fdd6c/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2001319/fbb9ecacfb0bba34946e5ef10c1fdd6c/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2001319/fbb9ecacfb0bba34946e5ef10c1fdd6c/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2001319/fbb9ecacfb0bba34946e5ef10c1fdd6c/1200x900n'},
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/1959786/03a892d771b7aa0a214c7d12dbea34c6/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/1959786/03a892d771b7aa0a214c7d12dbea34c6/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/1959786/03a892d771b7aa0a214c7d12dbea34c6/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/1959786/03a892d771b7aa0a214c7d12dbea34c6/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/1959786/03a892d771b7aa0a214c7d12dbea34c6/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/1959786/03a892d771b7aa0a214c7d12dbea34c6/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/1959786/03a892d771b7aa0a214c7d12dbea34c6/1200x900n'},
#     'preview': 'data:image/jpeg;base64,...'},
#    {'sizes': {'small': '//avatars.mds.yandex.net/get-autoru-vos/2172682/93b2e255ffed81ae4658ab0e3cc83c8a/small',
#      'thumb_m': '//avatars.mds.yandex.net/get-autoru-vos/2172682/93b2e255ffed81ae4658ab0e3cc83c8a/thumb_m',
#      '320x240': '//avatars.mds.yandex.net/get-autoru-vos/2172682/93b2e255ffed81ae4658ab0e3cc83c8a/320x240',
#      '456x342': '//avatars.mds.yandex.net/get-autoru-vos/2172682/93b2e255ffed81ae4658ab0e3cc83c8a/456x342',
#      '456x342n': '//avatars.mds.yandex.net/get-autoru-vos/2172682/93b2e255ffed81ae4658ab0e3cc83c8a/456x342n',
#      '1200x900': '//avatars.mds.yandex.net/get-autoru-vos/2172682/93b2e255ffed81ae4658ab0e3cc83c8a/1200x900',
#      '1200x900n': '//avatars.mds.yandex.net/get-autoru-vos/2172682/93b2e255ffed81ae4658ab0e3cc83c8a/1200x900n'},
#     'preview': 'data:image/jpeg;base64,...'}],
#   'mileage': 0,
#   'images_count': 6},
#  'sub_category': 'cars',
#  'vehicle_info': {'configuration': {'id': '22679065',
#    'body_type': 'ALLROAD_5_DOORS',
#    'doors_count': 5,
#    'auto_class': 'J',
#    'human_name': 'Внедорожник 5 дв.',
#    'trunk_volume_min': 615,
#    'trunk_volume_max': 1655,
#    'body_type_group': 'ALLROAD_5_DOORS',
#    'main_photo': {'sizes': {'orig': '//avatars.mds.yandex.net/get-verba/1030388/2a0000017641c483687436059c4170ad9154/orig',
#      'wizardv3mr': '//avatars.mds.yandex.net/get-verba/1030388/2a0000017641c483687436059c4170ad9154/wizardv3mr',
#      'cattouch': '//avatars.mds.yandex.net/get-verba/1030388/2a0000017641c483687436059c4170ad9154/cattouch'}}},
#   'complectation': {'id': '22688520',
#    'name': 'Status',
#    'available_options': ['cruise-control',
#     'multi-wheel',
#     'heated-wash-system',
#     'airbag-passenger',
#     'navigation',
#     'roof-rails',
#     'bas',
#     'lock',
#     'electro-mirrors',
#     'mirrors-heat',
#     '220v-socket',
#     'glonass',
#     'drowsy-driver-alert-system',
#     'automatic-lighting-control',
#     'passenger-seat-updown',
#     'collision-prevention-assist',
#     'computer',
#     'seat-transformation',
#     'android-auto',
#     'fabric-seats',
#     'airbag-side',
#     'abs',
#     'wheel-leather',
#     'auto-mirrors',
#     'asr',
#     'tinted-glass',
#     'esp',
#     'usb',
#     'audiopreparation',
#     'audiosystem-tv',
#     'front-centre-armrest',
#     'apple-carplay',
#     'front-seat-support',
#     'rear-camera',
#     'servo',
#     'drl',
#     'electro-window-back',
#     'reduce-spare-wheel',
#     'multizone-climate-control',
#     '17-inch-wheels',
#     'body-mouldings',
#     'park-assist-f',
#     'folding-front-passenger-seat',
#     'rear-seats-heat',
#     'wheel-heat',
#     'led-lights',
#     'park-assist-r',
#     'airbag-driver',
#     'isofix',
#     'drive-mode-sys',
#     'electro-window-front',
#     'light-sensor',
#     'hcc',
#     'airbag-curtain',
#     'leather-gear-stick',
#     'rain-sensor',
#     'tyre-pressure',
#     'audiosystem-cd',
#     'front-seats-heat',
#     'bluetooth',
#     'wheel-configuration2',
#     'wheel-configuration1',
#     'immo',
#     'windscreen-heat',
#     '12v-socket',
#     'third-rear-headrest'],
#    'vendor_colors': [{'body_color_id': 22701028,
#      'mark_color_id': 21391463,
#      'name_ru': 'Белый Pure',
#      'hex_codes': ['F2F3F2'],
#      'color_type': 'NOT_METALLIC',
#      'stock_color': {'hex_code': 'FAFBFB', 'name_ru': 'белый'},
#      'photos': [{'name': '34-front',
#        'sizes': {'orig': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/orig',
#         'wizardv3mr': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/wizardv3mr',
#         'wizardv3': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/wizardv3',
#         'cattouch': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/cattouch',
#         'small': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/small',
#         '320x240': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/320x240',
#         '1200x900': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/1200x900',
#         '1200x900n': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/1200x900n',
#         'thumb_m': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/thumb_m',
#         'full': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/full',
#         '832x624': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/832x624',
#         '456x342': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/456x342',
#         '120x90': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/120x90',
#         '92x69': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/92x69',
#         'islandoff': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/islandoff',
#         'thumb_s': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/thumb_s',
#         'thumb_s_2x': '//avatars.mds.yandex.net/get-verba/216201/2a0000017675f33acf47440e7392fb39106c/thumb_s_2x'}},
#       {'name': '34-back',
#        'sizes': {'orig': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/orig',
#         'wizardv3mr': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/wizardv3mr',
#         'wizardv3': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/wizardv3',
#         'cattouch': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/cattouch',
#         'small': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/small',
#         '320x240': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/320x240',
#         '1200x900': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/1200x900',
#         '1200x900n': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/1200x900n',
#         'thumb_m': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/thumb_m',
#         'full': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/full',
#         '832x624': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/832x624',
#         '456x342': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/456x342',
#         '120x90': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/120x90',
#         '92x69': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/92x69',
#         'islandoff': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/islandoff',
#         'thumb_s': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/thumb_s',
#         'thumb_s_2x': '//avatars.mds.yandex.net/get-verba/997355/2a0000017675f346b9199e85f4f1dc2c2a3c/thumb_s_2x'}},
#       {'name': 'side',
#        'sizes': {'orig': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/orig',
#         'wizardv3mr': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/wizardv3mr',
#         'wizardv3': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/wizardv3',
#         'cattouch': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/cattouch',
#         'small': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/small',
#         '320x240': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/320x240',
#         '1200x900': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/1200x900',
#         '1200x900n': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/1200x900n',
#         'thumb_m': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/thumb_m',
#         'full': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/full',
#         '832x624': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/832x624',
#         '456x342': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/456x342',
#         '120x90': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/120x90',
#         '92x69': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/92x69',
#         'islandoff': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/islandoff',
#         'thumb_s': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/thumb_s',
#         'thumb_s_2x': '//avatars.mds.yandex.net/get-verba/3587101/2a0000017675f34ea03653ea0c16b47fcf0b/thumb_s_2x'}},
#       {'name': 'back',
#        'sizes': {'orig': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/orig',
#         'wizardv3mr': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/wizardv3mr',
#         'wizardv3': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/wizardv3',
#         'cattouch': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/cattouch',
#         'small': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/small',
#         '320x240': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/320x240',
#         '1200x900': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/1200x900',
#         '1200x900n': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/1200x900n',
#         'thumb_m': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/thumb_m',
#         'full': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/full',
#         '832x624': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/832x624',
#         '456x342': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/456x342',
#         '120x90': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/120x90',
#         '92x69': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/92x69',
#         'islandoff': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/islandoff',
#         'thumb_s': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/thumb_s',
#         'thumb_s_2x': '//avatars.mds.yandex.net/get-verba/937147/2a0000017675f356b84d7fa7c7be7d7e4b5e/thumb_s_2x'}}],
#      'main_color': True}]},
#   'equipment': {'cruise-control': True,
#    'asr': True,
#    'tinted-glass': True,
#    'esp': True,
#    'usb': True,
#    'multi-wheel': True,
#    'audiosystem-tv': True,
#    'heated-wash-system': True,
#    'airbag-passenger': True,
#    'front-centre-armrest': True,
#    'navigation': True,
#    'apple-carplay': True,
#    'front-seat-support': True,
#    'roof-rails': True,
#    'bas': True,
#    'rear-camera': True,
#    'lock': True,
#    'servo': True,
#    'electro-mirrors': True,
#    'drl': True,
#    'electro-window-back': True,
#    'reduce-spare-wheel': True,
#    'multizone-climate-control': True,
#    'mirrors-heat': True,
#    '17-inch-wheels': True,
#    'park-assist-f': True,
#    'body-mouldings': True,
#    'folding-front-passenger-seat': True,
#    'rear-seats-heat': True,
#    'wheel-heat': True,
#    'led-lights': True,
#    '220v-socket': True,
#    'park-assist-r': True,
#    'glonass': True,
#    'airbag-driver': True,
#    'isofix': True,
#    'drive-mode-sys': True,
#    'electro-window-front': True,
#    'light-sensor': True,
#    'hcc': True,
#    'drowsy-driver-alert-system': True,
#    'automatic-lighting-control': True,
#    'airbag-curtain': True,
#    'passenger-seat-updown': True,
#    'collision-prevention-assist': True,
#    'computer': True,
#    'seat-transformation': True,
#    'android-auto': True,
#    'dha': True,
#    'fabric-seats': True,
#    'alloy-wheel-disks': True,
#    'leather-gear-stick': True,
#    'rain-sensor': True,
#    'airbag-side': True,
#    'tyre-pressure': True,
#    'audiosystem-cd': True,
#    'abs': True,
#    'bluetooth': True,
#    'front-seats-heat': True,
#    'wheel-leather': True,
#    'wheel-configuration2': True,
#    'wheel-configuration1': True,
#    'immo': True,
#    'windscreen-heat': True,
#    'auto-mirrors': True,
#    '12v-socket': True,
#    'third-rear-headrest': True},
#   'mark_info': {'code': 'VOLKSWAGEN',
#    'name': 'Volkswagen',
#    'ru_name': 'Фольксваген',
#    'logo': {'name': 'mark-logo',
#     'sizes': {'logo': '//avatars.mds.yandex.net/get-verba/1672712/2a0000016f0df4b586c4a2e5ce1b023e176a/logo',
#      'big-logo': '//avatars.mds.yandex.net/get-verba/1672712/2a0000016f0df4b586c4a2e5ce1b023e176a/dealer_logo'}}},
#   'model_info': {'code': 'TIGUAN',
#    'name': 'Tiguan',
#    'ru_name': 'Тигуан',
#    'morphology': {},
#    'nameplate': {'code': '', 'name': '', 'semantic_url': ''}},
#   'steering_wheel': 'LEFT',
#   'super_gen': {'id': '22678987',
#    'name': 'II Рестайлинг',
#    'ru_name': '2 Рестайлинг',
#    'year_from': 2020,
#    'price_segment': 'MEDIUM'},
#   'tech_param': {'id': '22680193',
#    'displacement': 1395,
#    'engine_type': 'GASOLINE',
#    'gear_type': 'FORWARD_CONTROL',
#    'transmission': 'ROBOT',
#    'power': 150,
#    'power_kvt': 110,
#    'human_name': '1.4 AMT (150 л.с.)',
#    'acceleration': 9.3,
#    'clearance_min': 191,
#    'fuel_rate': 6.8},
#   'vendor': 'EUROPEAN'},
#  'lk_summary': '1.4\xa0AMT (150\xa0л.с.), внедорожник, передний, бензин',
#  'multiposting': {}}

# %%
from_json[0]['vehicle_info']['configuration']['human_name']
# Out:
# 'Кабриолет'

# %%
from_json[60000]['vehicle_info']['configuration']['human_name']
# Out:
# 'Внедорожник 5 дв.'

# %%
# Took the idea from https://www.kaggle.com/sokolovaleks/sf-dst-10-p1-parsing-almira-andrey-sokolov
# and changed it to fit my requirements

# dictionary of the columns we need ( +/- what we have in test.csv)
dict_columns = {'bodyType':0, 'brand':0, 'color_hex':0, 'complectation_dict':0, 'equipment_dict':0, 
                'fuelType':0, 'modelDate':0, 'model_info':0, 'model_name':0, 'name':0, 'numberOfDoors':0, 'productionDate':0, 
                'vehicleConfiguration':0, 'vehicleTransmission':0, 'vendor':0,    
                'engineDisplacement':0, 'enginePower':0, 'description':0, 
                'mileage':0, 'Привод':0, 'Руль':0, 
                'Состояние':0, 'Владельцы':0, 'ПТС':0, 'Таможня':0, 
                'Владение':0, 'price':0}

def from_elem_to_dict(d_elem, dict_cols, result):
    """
    This function will be used to map json fields to dict_columns while looping through the list of JSONs. 
    """
    d_dict = dict_columns.copy()
    
    try: d_dict['bodyType'] = d_elem['vehicle_info']['configuration']['human_name']
    except: d_dict['bodyType'] = None

    try: d_dict['brand'] = d_elem['vehicle_info']['mark_info']['code']
    except: d_dict['brand'] = None

    try: d_dict['color_hex'] = d_elem['color_hex']
    except: d_dict['color_hex'] = None  
        
    try: d_dict['complectation_dict'] = d_elem['vehicle_info']['complectation']
    except: d_dict['complectation_dict'] = None     
        
    try: d_dict['equipment_dict'] = d_elem['vehicle_info']['equipment']
    except: d_dict['equipment_dict'] = None           

    try: d_dict['fuelType'] = d_elem['lk_summary'].split()[-1]
    except: d_dict['fuelType'] = None

    try: d_dict['modelDate'] = d_elem['vehicle_info']['super_gen']['year_from']
    except: d_dict['modelDate'] = None
        
    try: d_dict['model_info'] = d_elem['vehicle_info']['model_info']
    except: d_dict['model_info'] = None        
        
    try: d_dict['model_name'] = d_elem['vehicle_info']['model_info']['ru_name']
    except: d_dict['model_name'] = None             

    try: d_dict['name'] =  d_elem['vehicle_info']['tech_param']['human_name']
    except: d_dict['name'] = None

    try: d_dict['numberOfDoors'] = d_elem['vehicle_info']['configuration']['doors_count']
    except: d_dict['numberOfDoors'] = None

    try: d_dict['productionDate'] = d_elem['documents']['year']
    except: d_dict['productionDate'] = None

    try: d_dict['vehicleTransmission'] = d_elem['vehicle_info']['tech_param']['transmission']
    except: d_dict['vehicleTransmission'] = None
        
    try: d_dict['vendor'] = d_elem['vehicle_info']['vendor']
    except: d_dict['vendor'] = None    

    try: d_dict['engineDisplacement'] = d_elem['vehicle_info']['tech_param']['human_name'].split()[0]
    except: d_dict['engineDisplacement'] = None

    try: d_dict['vehicleConfiguration'] = d_elem['vehicle_info']['configuration']
    except: d_dict['vehicleConfiguration'] = None

    try: d_dict['enginePower'] = d_elem['vehicle_info']['tech_param']['power']
    except: d_dict['enginePower'] = None

    try: d_dict['description'] = d_elem['description']
    except: d_dict['description'] = None

    try: d_dict['mileage'] = d_elem['state']['mileage']
    except: d_dict['mileage'] = None

    try: d_dict['Привод'] = d_elem['lk_summary'].split(', ')[-2]
    except: d_dict['Привод'] = None

    try: d_dict['Руль'] = d_elem['vehicle_info']['steering_wheel']
    except: d_dict['Руль'] = None

    try: d_dict['Состояние'] = d_elem['section']
    except: d_dict['Состояние'] = None

    try: d_dict['Владельцы'] = d_elem['documents']['owners_number']
    except: d_dict['Владельцы'] = None

    try: d_dict['ПТС'] = d_elem['documents']['pts']
    except: d_dict['ПТС'] = None

    try: d_dict['Таможня'] = d_elem['documents']['custom_cleared']
    except: d_dict['Таможня'] = None

    try: d_dict['Владение'] =  d_elem['documents']['purchase_date']
    except: d_dict['Владение'] = None

    try: d_dict['price'] = d_elem['price_info']['RUR']
    except: d_dict['price'] = None

    result.append(d_dict)

# %%
result = []

for i in from_json:
    from_elem_to_dict(d_elem=i, dict_cols=dict_columns, result=result)

# %%
df_result = pd.DataFrame(result)

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60488 entries, 0 to 60487
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bodyType              60486 non-null  object
#  1   brand                 60488 non-null  object
#  2   color_hex             60488 non-null  object
#  3   complectation_dict    60488 non-null  object
#  4   equipment_dict        60488 non-null  object
#  5   fuelType              60488 non-null  object
#  6   modelDate             60486 non-null  float64
#  7   model_info            60488 non-null  object
#  8   model_name            60488 non-null  object
#  9   name                  60486 non-null  object
#  10  numberOfDoors         60486 non-null  float64
#  11  productionDate        60488 non-null  int64
#  12  vehicleConfiguration  60486 non-null  object
#  13  vehicleTransmission   60486 non-null  object
#  14  vendor                60488 non-null  object
#  15  engineDisplacement    60486 non-null  object
#  16  enginePower           60486 non-null  float64
#  17  description           57970 non-null  object
#  18  mileage               60488 non-null  int64
#  19  Привод                60486 non-null  object
#  20  Руль                  60488 non-null  object
#  21  Состояние             60488 non-null  object
#  22  Владельцы             46646 non-null  float64
#  23  ПТС                   60202 non-null  object
#  24  Таможня               60488 non-null  bool
#  25  Владение              14417 non-null  object
#  26  price                 60237 non-null  float64
# dtypes: bool(1), float64(5), int64(2), object(19)
# memory usage: 12.1+ MB

# %%
df_result.to_csv('own_train_set.csv')

# %%
df_result.to_excel('own_train_set.xlsx')
